# %%
# task1
class Car:
  count=0
  def __init__(self):
    Car.count+=1
    print("Car is nice",Car.count)
maruti = Car()
bmw = Car()
honda = Car()
# Out:
# Car is nice 1
# Car is nice 2
# Car is nice 3
