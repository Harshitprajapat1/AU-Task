# %%
#Q1 :- Print the given strings as per stated format
# "Data" "Science" "Mentorship" "Program" "By" "CampusX"
# Data-Science-Mentorship-Program-started-By-CampusX
print("Data","Science","Mentorship","Program","By","CampusX",sep="-")
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %%
#Q2:- Write a program that will convert celsius value to fahrenheit
celsius=int(input("Enter the celsius "))
fahrenheit=celsius*(9/5)+32
print(f"Fahrenheit is : {fahrenheit}")
# Out:
# Enter the celsius 40
# Fahrenheit is : 104.0

# %%
#Q3:- Take 2 numbers as input from the user.Write a program to swap
# the numbers without using any special python syntax
swap_num1=int(input("Enter first number : "))
swap_num2=int(input("Enter second number : "))
temp=0
temp=swap_num1
swap_num1=swap_num2
swap_num2=temp
print("Number 1 : ",swap_num1)
print("Number 2 : ",swap_num2)
# Out:
# Enter first number : 4
# Enter second number : 5
# Number 1 :  5
# Number 2 :  4

# %%
# Q4:- Write a program to find the euclidean distance between two
# coordinates.Take both the coordinates from the user as input.
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
# Take input for the second point
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))
distance=(((x2-x1)**2)+((y2-y1)**2))**0.5
print(distance)
# Out:
# Enter x1: 3
# Enter y1: 4
# Enter x2: 5
# Enter y2: 7
# 3.605551275463989

# %%
# Q5:- Write a program to find the simple interest when the value of
# principle,rate of interest and time period is provided by the user.
time=int(input("Enter the Time "))
rate=int(input("Enter the Rate "))
principle=int(input("Enter the Amount "))
simple_interest=time*rate*principle/100
print(simple_interest)
# Out:
# Enter the Time 4
# Enter the Rate 8
# Enter the Amount 80000
# 25600.0

# %%
# Q6:- Write a program that will tell the number of dogs and chicken are
# there when the user will provide the value of total heads and legs.
# For example: Input: heads -> 4 legs -> 12 Output: dogs -> 2 chicken -> 2
head=int(input("Enter Heads: "))
legs=int(input("Enter Legs : "))
if (legs<2)and (head<1):
  print("NOT Posible! please enter a valid input")
else:
  dogs = (legs - 2 * head) // 2
  chickens = head - dogs
  if dogs < 0 or chickens < 0:
      print("Not possible! Please enter valid inputs")
  else:
      print("Dogs:", dogs)
      print("Chickens:", chickens)
# Out:
# Enter Heads: 3
# Enter Legs : 8
# Dogs: 1
# Chickens: 2

# %%
# Q7:- Write a program to find the sum of squares of first n natural
# numbers where n will be provided by the user
n=int(input("Enter a number "))
sum=0
if n<0:
  print("Enter a valid input!")
else:
  for i in range(n+1):
    sum+=i*i
  print(sum)
# Out:
# Enter a number 4
# 30

# %%
# Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term
# of the series. Assume all inputs are provided by the user.
# Sn = (n/2)[2a + (n-1)d]
a=int(input("Enter first term "))
b=int(input("Enter second term "))
n=int(input("Enter the number of term series "))
d=a-b
an=a+(n-1)*d
print("Nth term of series : ",an)
# Out:
# Enter first term 8
# Enter second term 4
# Enter the number of term series 9
# Nth term of series :  40

# %%
# Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the
# numerator and denominator values of the fractions from the user.
import math
n1=int(input("enter first numerator : "))
d1=int(input("enter first dwmoinator: "))
n2=int(input("enter second numerator : "))
d2=int(input("enter second dwmoinator: "))
lcm=math.lcm(d1,d2)
m1=n1*(lcm//d1)
m2=n2*(lcm//d2)
s=m1+m2
print(s,"/",lcm)
# Out:
# enter first numerator : 8
# enter first dwmoinator: 10
# enter second numerator : 3
# enter second dwmoinator: 20
# 19 / 20

# %%
# Q10:- Given the height, width and breadth of a milk tank, you have to
# find out how many glasses of milk can be obtained? Assume all the
# inputs are provided by the user.
# Input: Dimensions of the milk tank H = 20cm, L = 20cm, B = 20cm Dimensions of the glass h =
# 3cm, r = 1cm

m_h=20
m_l=20
m_b=20
g_h=3
g_r=1
volume_tank=m_h*m_l*m_b
volume_glass=3.14*(g_r**2)*g_h
total_glass=volume_tank//volume_glass
print(total_glass)
# Out:
# 849.0
