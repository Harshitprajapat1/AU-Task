# %%
# session 2 task
# Problem 1: Write a program that will give you in hand monthly salary after deduction on CTC - HRA(10%), DA(5%), PF(3%) and taxes deduction as below:
# Salary(Lakhs) : Tax(%)
# • Below 5 : 0%
# • 5-10 : 10%
# • 10-20 : 20%
# • aboove 20 : 30%


salary=int(input("enter the anual salary salary "))
hra=(10/100)*salary
da=(5/100)*salary
pf=(3/100)*salary
ctc=salary-(hra+da+pf)
if ctc < 500000:
  print("Final salary is ",ctc)
  print("monthly salary is : ",ctc//12)
elif ctc > 500000 and ctc<1000000:
  tax=(10/100)*ctc
  tax_after_salary=ctc-tax
  print("Final salary is ",tax_after_salary)
  print("monthly salary is : ",tax_after_salary//12)
elif ctc >1000000 and ctc < 2000000:
  tax=(20/100)*ctc
  tax_after_salary=ctc-tax
  print("Final salary is ",tax_after_salary)
  print("monthly salary is : ",tax_after_salary//12)
else:
  tax=(30/100)*ctc
  tax_after_salary=ctc-tax
  print("Final salary is ",tax_after_salary)
  print("monthly salary is : ",tax_after_salary//12)
# Out:
# enter the anual salary salary 1200000
# Final salary is  885600.0
# monthly salary is :  73800.0

# %%
# Problem 2: Write a program that take a user input of three angles and
# will find out whether it can form a triangle or not
angle1=int(input("Enter angle first : "))
angle2=int(input("Enter angle second : "))
angle3=int(input("Enter angle third : "))
Tringle=angle1+angle2+angle3
if Tringle==180:
  print("This is a Tringle")
else:
  print("This is not a tringle")
# Out:
# Enter angle first : 60
# Enter angle second : 60
# Enter angle third : 60
# This is a Tringle

# %%
# Problem 3: Write a program that will take user input of cost price and
# selling price and determines whether its a loss or a profit.
cost=int(input("Enter the cost of product "))
selling=int(input("Enter the selling price "))
if cost>selling:
  print("Loss! Loss is : ",cost-selling)
else:
  print("Profit! Profig is : ", selling-cost)
# Out:
# Enter the cost of product 124324324
# Enter the selling price 133543534
# Profit! Profig is :  9219210

# %%
# Problem 4: Write a menu-driven program -
# 1. cm to ft
# 2. km to miles
# 3. USD to INR
# 4. exit
while True:
  print("1. cm to ft \n 2. km to miles \n 3. USD to INR \n 4. exit")
  choices=int(input("Enter Your Choices : "))
  if choices==1:
    cm=int(input("Enter the Centimeter : "))

# %%
# Problem 5: Write a menu-driven program -
# 1. cm to ft
# 2. km to miles
# 3. USD to INR
# 4. exit

while True:
  print(" 1. cm to ft \n 2. km to miles \n 3. USD \n 4. exit")
  choice=int(input("Choose a opration number "))
  if choice==1:
    Centimeters=int(input("Enter the centimeters "))
    Feet=Centimeters/30.48
    print(Feet, "Feet\n")
  elif choice==2:
    Kilometers=int(input("Enter the Kilometers "))
    Miles=Kilometers*0.621371
    print(Miles, "Miles\n")
  elif choice==3:
    usd=int(input("Enter the USD "))
    inr=usd*84.72
    print(inr, "INR\n")
  elif choice == 4:
    break
  else:
      print("Invalid choice. Please enter 1, 2, 3, or 4.")
# Out:
#  1. cm to ft
#  2. km to miles
#  3. USD
#  4. exit
# Choose a opration number 1
# Enter the centimeters 76
# 2.493438320209974 Feet
#
#  1. cm to ft
#  2. km to miles
#  3. USD
#  4. exit
# Choose a opration number 4

# %%
# Problem 6 - Exercise 12: Display Fibonacci series up to 10 terms.
# Note: The Fibonacci Sequence is a series of numbers. The next number is found by adding up the
# two numbers before it. The first two numbers are 0 a

# %%
from re import A
temp=0
a=0
b=1
for i in range(10):
  print(a,end=" ")
  temp=a
  a=b
  b=a+b
# Out:
# 0 1 2 4 8 16 32 64 128 256

# %%
# Problem 7 - Find the factorial of a given number.
# Write a program to use the loop to find the factorial of a given number.
# The factorial (symbol: !) means to multiply all whole numbers from the chosen number down to 1
value=int(input("enter the value "))
fact=1
for i in range(1,value+1):
  fact*=i
print("factorial ", fact)
# Out:
# enter the number to find a factorial : 5
# 120

# %%
# Problem 9 - Reverse a given integer number.
n=int(input("Enter the number "))
reverse=0
while n>0:
  last_digit=n%10
  reverse=reverse*10+last_digit
  n=n//10
print(reverse)
# Out:
# Enter the number 789
# 987

# %%
# Problem 8: Take a user input as integer N. Find out the sum from 1 to N.
# If any number if divisible by 5, then skip that number. And if the sum is
# greater than 300, don't need to calculate the sum further more. Print
# the final result. And don't use for loop to solve this problem.
n=int(input("enter the number to be print sum "))
s=0
while n>0:
  if n%5!=0:
     s+=n
  if s>300:
    s-=n
    break
  n-=1
print(s)
# Out:
# enter the number to be print sum 30
# 297

# %%
# Problem 9: Write a program that keeps on accepting a number from the
# user until the user enters Zero. Display the sum and average of all the
# numbers.
cou=0
sum=0
while True:
  number=int(input("Enter numbers ! but you want to exit find out sum and avrage enter 0  "))
  sum+=number
  if number==0:
    break
  cou+=1
print("Sum is : ",sum)
avg=sum//cou
print("Avrage is : ",avg)
# Out:
# Enter numbers ! but you want to exit find out sum and avrage enter 0  1
# Enter numbers ! but you want to exit find out sum and avrage enter 0  2
# Enter numbers ! but you want to exit find out sum and avrage enter 0  3
# Enter numbers ! but you want to exit find out sum and avrage enter 0  4
# Enter numbers ! but you want to exit find out sum and avrage enter 0  5
# Enter numbers ! but you want to exit find out sum and avrage enter 0  6
# Enter numbers ! but you want to exit find out sum and avrage enter 0  7
# Enter numbers ! but you want to exit find out sum and avrage enter 0  8
# Enter numbers ! but you want to exit find out sum and avrage enter 0  9
# Enter numbers ! but you want to exit find out sum and avrage enter 0  0
# Sum is :  45
# Avrage is :  5

# %%
# Problem 10: Write a program which will find all such numbers which are divisible by 7 but
# are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should
# be printed in a comma-separated sequence on a single line
n=2000
s=0
while n <=3200:
  if n%7==0 and n%5!=0:
    print(n,end=",")
  n+=1
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %%
# Problem 11: Write a program, which will find all such numbers between 1000 and 3000
# (both included) such that each digit of the number is an even number. The numbers obtained
# should be printed in a space-separated sequence on a single line
for i in range(1000,3000):
  c=i
  flag=1
  while c>0:
    la_di=c%10
    if la_di%2!=0:
      flag=0
      break
    c//=10
  if flag==1:
    print(i,end=" ")
# Out:
# 2000 2002 2004 2006 2008 2020 2022 2024 2026 2028 2040 2042 2044 2046 2048 2060 2062 2064 2066 2068 2080 2082 2084 2086 2088 2200 2202 2204 2206 2208 2220 2222 2224 2226 2228 2240 2242 2244 2246 2248 2260 2262 2264 2266 2268 2280 2282 2284 2286 2288 2400 2402 2404 2406 2408 2420 2422 2424 2426 2428 2440 2442 2444 2446 2448 2460 2462 2464 2466 2468 2480 2482 2484 2486 2488 2600 2602 2604 2606 2608 2620 2622 2624 2626 2628 2640 2642 2644 2646 2648 2660 2662 2664 2666 2668 2680 2682 2684 2686 2688 2800 2802 2804 2806 2808 2820 2822 2824 2826 2828 2840 2842 2844 2846 2848 2860 2862 2864 2866 2868 2880 2882 2884 2886 2888

# %%
###Problem 12: A robot moves in a plane starting from the original point (0,0). The robot can
# move toward UP, DOWN, LEFT and RIGHT with a given steps. The trace of robot movement is
# shown as the following:
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# !

# The numbers after the direction are steps.
# ! means robot stop there.
# Please write a program to compute the distance from current position after a sequence of
# movement and original point.If the distance is a float, then just print the nearest integer.
# Example:
# input:
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# !
# Output:
# 2
import math
up=0
down=0
right=0
left=0
x=0
y=0

print("\n1.UP\n2.DOWN\n3.RIGHT\n4.LEFT\n5.(exit) !")
while True:
  a=input("Enter your move ")
  if a=="up":
    u=int(input("Enter Move number "))
    y+=u
  elif a=="down":
    u=int(input("Enter Move number "))
    y-=u
  elif a=="right":
    u=int(input("Enter Move number "))
    x+=u
  elif a=="left":
    u=int(input("Enter Move number "))
    x-=u
  elif a=="!":
    break
  else:
    print("Invalid input")
print(x,y)
Distance=math.sqrt(x**2 + y**2)
print("final distance is ",Distance)
# Out:
# 1.UP
# 2.DOWN
# 3.RIGHT
# 4.LEFT
# 5.(exit) !
# Enter your move up
# Enter Move number 8
# Enter your move down
# Enter Move number 2
# Enter your move right
# Enter Move number 6
# Enter your move left
# Enter Move number 3
# Enter your move !
# 3 6
# final distance is  6.708203932499369

# %%
# Problem 13:Write a program to print whether a given number is a prime number or not
pn=int(input("Enter a number to check number is prime or not : "))
sqrt=int(pn**0.5)
if pn<=1:
  print("Not a prime enter valid number")
else:
  for i in range(2,sqrt+1):
    if pn%i==0:
      print("Number is not prime")
      break
  else:
    print("Number is prime")
# Out:
# Enter a number to check number is prime or not : 22
# Number is not prime

# %%
# Problem 14:Print all the Armstrong numbers in a given range. Range will be provided by
# the user Armstrong number is a number that is equal to the sum of cubes of its digits. For
# example 0, 1, 153, 370, 371 and 407 are the Armstrong numbers
r=int(input("Enter the number of range "))

for i in range(1,r+1):
  c=i
  sum=0
  while c>0:
    la_di=c%10
    sum+=la_di**3
    c//=10
  if sum==i:
    print(i,end=" ")
# Out:
# Enter the number of range 1000
# 1 153 370 371 407

# %%
# Problem 15:Calculate the angle between the hour hand and minute hand.
# Note: There can be two angles between hands; we need to print a minimum of two. Also, we
# need to print the floor of the final result angle. For example, if the final angle is 10.61, we need to
# print 10.
# Input: H = 9 , M = 0 Output: 90 Explanation: The minimum angle between hour and minute hand
# when the time is 9 is 90 degress.
hours=int(input("Enter the Houre "))
minutes=int(input("Enter the minutes "))
De_minutes=6*minutes
de_houre=30*hours + 0.5*De_minutes
dif=de_houre-De_minutes
angle=int(360-dif)
print("Angle is : ",angle)
# Out:
# Enter the Houre 11
# Enter the minutes 30
# Angle is :  120

# %%
# Problem 15:Given two rectangles, find if the given two rectangles overlap or not. A
# rectangle is denoted by providing the x and y coordinates of two points: the left top corner and
# the right bottom corner of the rectangle. Two rectangles sharing a side are considered
# overlapping. (L1 and R1 are the extreme points of the first rectangle and L2 and R2 are the
# extreme points of the second rectangle).
# Note: It may be assumed that the rectangles are parallel to the coordinate axis.
